# %% [markdown]
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-3 col-md-3 col-lg-3">
# 	<!-- logo -->
#     <div class="img-responsive">
#       <img src="https://www.emagister.com/es/albums/4/5/4/1/6/xl_cropped_6c5a85b217ef4975e89e78359d8d23ca.jpg" title="Curso Análisis de Datos con Python" alt="Curso Análisis de Datos con Python">
#     </div>
# 	<!-- logo -->
#   </div>
# <!-- ---------------------------------------------------- -->
#   <div class="col-sm-6 col-md-6 col-lg-6">
# 	<!-- Pandas Tutorial -->
# 	  <center>
# 	    <br>
#         <h1>Proyecto Final Sección 2</h1>
#  <h1>Proyecto Análisis de Datos de La Liga 2019 - 2020</h1>
#         <br>
#         <br>
#         <strong> Análisis de Datos con Python </strong><a href="https://culture-lab.es/" target="_blank"><strong>https://culture-lab.es/</strong></a>
# 	  </center>
#     <!-- Pandas Tutorial -->
#
#   </div>
# <!-- ---------------------------------------------------- -->

# %% [markdown]
#   La temporada * 2019-20 de La Liga *, fue la 89 desde su creación. La temporada comenzó el 17 de agosto de 2018 y terminó el 26 de mayo de 2019. Los partidos de la temporada 2018-19 se anunciaron el 24 de julio de 2018. *Esta fue la segunda temporada de La Liga con VAR*.
#
#
# * Barcelona * fueron los * campeones defensores * después de ganar La Liga la temporada pasada por * 25ª vez *. * Huesca, Rayo Vallecano y Valladolid * se unen como los clubes promovidos de la * 2017-18 División Segunda *. Reemplazaron a * Málaga, Las Palmas y Deportivo La Coruña * que fueron relegados a * Segunda División * 2018-19. * Barcelona * fue coronado como * ganador de la liga * por segunda temporada consecutiva el 28 de abril, después de derrotar a * Levante 1-0 con 3 juegos de sobra *.
#
# * **About the Project:**
#
# En este proyecto analizaremos el patrón en los datos que nos ayudarán a obtener más información sobre la temporada de La Liga.
#
# ---

# %% [markdown]
# ### 1. Importación de Librerías:
#
# * **Packages Imported** :-
#
#     1. sys: access to system parameters.
#     2. numpy : for numerical computation.
#     3. pandas: for data manipulation and analysis.
#     4. ipywidgets: añadir interactividad a las tablas

# %%
## load packages
import sys
import numpy as np
import pandas as pd
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
## display and HTML modules 
from IPython.display import display, HTML

## style module from matplotlib
import matplotlib.style as style

## pyplot module from matplotlib
import matplotlib.pyplot as plt

# %%
## set pandas to show all columns
pd.set_option('display.max_columns', None)

## disable the SettingwithCopyWarning
pd.options.mode.chained_assignment = None

## set style for our plot
style.use('ggplot')

## inline magic function
# %matplotlib inline

# %%
## so that functions from main_functions.ipynb file can be used
# %run main_functions.ipynb

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Los Datos:
#
# * **Overview:**
#
# El conjunto de datos contiene información sobre todos y cada uno de los partidos jugados en la temporada de La Liga 2018-19, y con la ayuda de los datos intentaremos obtener información sobre la temporada.
#
#   El conjunto de datos se descarga desde: http://football-data.co.uk/data.php

# %% [markdown]
# * The dataset contains following fields:
#
#     * Div : División (Primera, Segunda) como he descargado sólo el de 1ra siempre aparecerá 1
#     * Date : Día del Partido (dd/mm/yy)
#     * HomeTeam : Equipo Local
#     * AwayTeam : Equipo Visitante
#     * FTHG : (Full Time Home Team Goals) Goles de Local en el tiempo completo
#     * FTAG : (Full Time Away Team Goals) Goles de Visitante en el tiempo completo
#     * FTR : (Full Time Result) Resultado Final en tiempo Completo (H=Home Win, D=Draw, A=Away Win)
#     * HTHG : (Half Time Home Team Goal) Goles del equipo local al medio tiempo
#     * HTAG : (Half Time Away Team) Goals Goles del equipo visitante al medio tiempo
#     * HTR : (Half Time Result) Resultado en el medio tiempo (H=Home Win, D=Draw, A=Away Win)
#     * HS : (Home Team Shots) Remates equipo local
#     * AS : (Away Team Shots) Remates equipo visitante
#     * HST : (Home Team Shots on Target) Remates equipo local al arco
#     * AST : (Away Team Shots on Target) Remates equipo visitante al arco
#     * HF : (Home Team Fouls) Committed Faltas Cometidas equipo local
#     * AF : (Away Tema Fouls) Committed Faltas Cometidas equipo visitante
#     * HC : (Home Team Corners) Corners equipo local
#     * AC : (Away Team Corners) Corners equipo visitante
#     * HY : (Home Team Yellow Cards) Tarjetas Amarillas equipo local
#     * AY : (Away Team Yellow Cards) Tarjetas Amarillas equipo visitante
#     * HR : (Home Team Red Cards) Tarjetas Rojas equipo local
#     * AR : (Away Team Red Cards) Tarjetas Rojas equipo visitante
#
#
# * Note: No estamos incluyendo las * columnas de apuestas * en nuestro proyecto.

# %% [markdown]
# * **Leer los datos del archivo laliga_2018_19.csv.**

# %%
## laliga almacenará el conjunto de datos de la_liga_2018_2019
laliga = pd.read_csv('laliga2019_2020.csv')

# %% [markdown]
# * **Usa las funciones básicas para ver el conjunto de datos y la información sobre el conjunto de datos.**

# %%
## Ver los diez primeros registros de la base de datos
laliga.head(10)
# Out:
#    Div        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  SP1  17/08/2018        Betis     Levante     0     3   A     0     1   A
# 1  SP1  17/08/2018       Girona  Valladolid     0     0   D     0     0   D
# 2  SP1  18/08/2018    Barcelona      Alaves     3     0   H     0     0   D
# 3  SP1  18/08/2018        Celta     Espanol     1     1   D     0     1   A
# 4  SP1  18/08/2018   Villarreal    Sociedad     1     2   A     1     1   D
# 5  SP1  19/08/2018        Eibar      Huesca     1     2   A     0     2   A
# 6  SP1  19/08/2018  Real Madrid      Getafe     2     0   H     1     0   H
# 7  SP1  19/08/2018    Vallecano     Sevilla     1     4   A     0     3   A
# 8  SP1  20/08/2018   Ath Bilbao     Leganes     2     1   H     1     1   D
# 9  SP1  20/08/2018     Valencia  Ath Madrid     1     1   D     0     1   A
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR  B365H  B365D  B365A  \
# ...

# %% [markdown]
# * **Seleccionar las mejores columnas del conjunto de datos:**
#
#     * Como solo queremos las primeras 22 columnas, todas las otras columnas son básicamente las columnas de apuestas.
#     * Entonces dividiremos el marco de datos que nos dará el conjunto de datos que tiene las primeras 22 columnas.

# %%
## slice the dataset
laliga = laliga.iloc[:,:22]

# %%
## use head() function to see dataset's first few rows
laliga.head(10)
# Out:
#    Div        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  SP1  17/08/2018        Betis     Levante     0     3   A     0     1   A
# 1  SP1  17/08/2018       Girona  Valladolid     0     0   D     0     0   D
# 2  SP1  18/08/2018    Barcelona      Alaves     3     0   H     0     0   D
# 3  SP1  18/08/2018        Celta     Espanol     1     1   D     0     1   A
# 4  SP1  18/08/2018   Villarreal    Sociedad     1     2   A     1     1   D
# 5  SP1  19/08/2018        Eibar      Huesca     1     2   A     0     2   A
# 6  SP1  19/08/2018  Real Madrid      Getafe     2     0   H     1     0   H
# 7  SP1  19/08/2018    Vallecano     Sevilla     1     4   A     0     3   A
# 8  SP1  20/08/2018   Ath Bilbao     Leganes     2     1   H     1     1   D
# 9  SP1  20/08/2018     Valencia  Ath Madrid     1     1   D     0     1   A
#
#    HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0  22   6    8    4  10  10   5   3   0   2   0   0
# ...

# %%
laliga.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Div       380 non-null    object
#  1   Date      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  HS        380 non-null    int64
#  11  AS        380 non-null    int64
#  12  HST       380 non-null    int64
#  13  AST       380 non-null    int64
#  14  HF        380 non-null    int64
#  15  AF        380 non-null    int64
#  16  HC        380 non-null    int64
#  17  AC        380 non-null    int64
#  18  HY        380 non-null    int64
#  19  AY        380 non-null    int64
# ...

# %% [markdown]
# * **Resumen del Dataframe -- using info():**
#
#
# * Hay un total de 380 filas, lo que significa que se jugaron 380 partidos en toda la temporada.
#     * El dataframe contiene 22 columnas: 16 tienen valores enteros y 6 tienen valores de texto.
#     * Ninguna columna tiene valores de NaN.

# %%
## use describe method()
laliga.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.452632    1.134211    0.544737    0.513158   13.873684   10.434211
# std      1.146461    1.134905    0.681918    0.756562    5.048560    3.952006
# min      0.000000    0.000000    0.000000    0.000000    3.000000    2.000000
# 25%      1.000000    0.000000    0.000000    0.000000   10.000000    8.000000
# 50%      1.000000    1.000000    0.000000    0.000000   13.000000   10.000000
# 75%      2.000000    2.000000    1.000000    1.000000   17.000000   13.000000
# max      8.000000    6.000000    3.000000    5.000000   34.000000   21.000000
#
#               HST         AST          HF          AF          HC          AC  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     4.834211    3.589474   13.631579   13.450000    5.573684    4.021053
# ...

# %% [markdown]
# * **Borra la columna Div que indica la primera división.**

# %%
laliga.drop('Div', axis=1, inplace=True)

# %% [markdown]
# * **Revisa el tipo de dato de la columna Date.**

# %%
## original datatype of Date field
type(laliga['Date'].iloc[0])
# Out:
# str

# %% [markdown]
#  * **cambia el tipo de dato a timestamp object**

# %%
## change the datatype from str to a timestamp object
laliga['Date'] = pd.to_datetime(arg=laliga['Date'], dayfirst=True)

# %% [markdown]
# * **Revisa nuevamente el tipo de dato de la columna Date.**

# %%
## changed datatype of Date field
type(laliga['Date'].iloc[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# * **Crear 3 nuevas columnas:**
#     * Goles en casa en la segunda mitad (SHHG)
#     * Goles de vistante en la segunda mitad (SHAG)
#     * Resultado de la segunda mitad (SHR)

# %%
## create SHHG using FTHG and HTHG
loc = 9
column = 'SHHG'
value = laliga['FTHG'] - laliga['HTHG']
laliga.insert(loc, column, value)

# %%
## create SHAG using FTAG and HTAG
loc = 10
column = 'SHAG'
value = laliga['FTAG'] - laliga['HTAG']
laliga.insert(loc, column, value)

# %%
## create SHR using SHHG and SHAG
value = laliga['SHHG'] - laliga['SHAG']
value = value.tolist()

## computing result based on the second half final goal tally
for i in range(len(value)):
    if value[i] < 0:
        value[i] = 'A'
    elif value[i] == 0 :
        value[i] = 'D'
    else:
        value[i] = 'H'

value = pd.Series(data=value)        
loc = 11
column = 'SHR'
laliga.insert(loc, column, value)

# %%
## view the dataframe
laliga.head(10)
# Out:
#         Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  SHHG  \
# 0 2018-08-17        Betis     Levante     0     3   A     0     1   A     0
# 1 2018-08-17       Girona  Valladolid     0     0   D     0     0   D     0
# 2 2018-08-18    Barcelona      Alaves     3     0   H     0     0   D     3
# 3 2018-08-18        Celta     Espanol     1     1   D     0     1   A     1
# 4 2018-08-18   Villarreal    Sociedad     1     2   A     1     1   D     0
# 5 2018-08-19        Eibar      Huesca     1     2   A     0     2   A     1
# 6 2018-08-19  Real Madrid      Getafe     2     0   H     1     0   H     1
# 7 2018-08-19    Vallecano     Sevilla     1     4   A     0     3   A     1
# 8 2018-08-20   Ath Bilbao     Leganes     2     1   H     1     1   D     1
# 9 2018-08-20     Valencia  Ath Madrid     1     1   D     0     1   A     1
#
#    SHAG SHR  HS  AS  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0     2   A  22   6    8    4  10  10   5   3   0   2   0   0
# ...

# %% [markdown]
# * El proceso de limpieza de datos se ha realizado. Ahora podemos avanzar y hacer la tabla de la liga basada en el conjunto de datos que tenemos.

# %% [markdown]
# ### Total de partidos jugados en la temporada

# %%
total_partidos = laliga.shape[0]

print('Se jugaron: {}  partidos'.format(total_partidos))
# Out:
# Se jugaron: 380  partidos

# %% [markdown]
# ### Porcentajes de partidos ganados por el equipo local, empatados y ganados por el equipo visitante

# %%
total_partidos = laliga.shape[0]
ganados_local = len(laliga[laliga.FTR == 'H']['FTR'])
empate = len(laliga[laliga.FTR == 'D']['FTR'])
ganados_visitante = laliga[laliga.FTR == 'A']['FTR'].shape[0]

#Ganados, empatados y perdidos
mensaje = "Partidos ganados por el equipo local:      {:5} ({:5.2f}%)"
print(mensaje.format(ganados_local, round((ganados_local/total_partidos) * 100, 2)))
mensaje = "Partidos empatados:                        {:5} ({:5.2f}%)"
print(mensaje.format(empate, round((empate/total_partidos) * 100, 2) ))
mensaje = "Partidos ganados por el equipo visitante:  {:5} ({:5.2f}%)"
print(mensaje.format(ganados_visitante, round((ganados_visitante/total_partidos) * 100,2)))
# Out:
# Partidos ganados por el equipo local:        168 (44.21%)
# Partidos empatados:                          110 (28.95%)
# Partidos ganados por el equipo visitante:    102 (26.84%)

# %%
data = {'Partidos': ['Ganados', 'Empatados', 'Perdidos'], 'Porcentaje': [round((ganados_local/total_partidos) * 100, 2), round((empate/total_partidos) * 100, 2),round((ganados_visitante/total_partidos) * 100,2) ]}
partidos = pd.DataFrame.from_dict(data)
partidos
# Out:
#     Partidos  Porcentaje
# 0    Ganados       44.21
# 1  Empatados       28.95
# 2   Perdidos       26.84

# %%
partidos.groupby(['Partidos']).sum().plot(kind='pie', y='Porcentaje')

# %% [markdown]
# ### Cantidad de Goles por Partido de local, visitante de todos los equipos y por partido

# %%
goles_local = laliga.FTHG.sum()
goles_visitante = laliga.FTAG.sum()

#Goles y remates
mensaje = "Goles marcados por el equipo local:        {:5} ({:5.2f} por partido)"
print(mensaje.format(goles_local, round(goles_local/total_partidos, 2)))
mensaje = "Goles marcados por el equipo vistante:     {:5} ({:5.2f} por partido)"
print(mensaje.format(goles_visitante, round(goles_visitante/total_partidos, 2)))
# Out:
# Goles marcados por el equipo local:          552 ( 1.45 por partido)
# Goles marcados por el equipo vistante:       431 ( 1.13 por partido)

# %%
data = {'Tipo': ['Local', 'Visitante'], 'Goles': [goles_local, goles_visitante]}
goles = pd.DataFrame.from_dict(data)
goles
# Out:
#         Tipo  Goles
# 0      Local    552
# 1  Visitante    431

# %%
goles.groupby(['Tipo']).sum().plot(kind='pie', y='Goles')

# %% [markdown]
# ### Remates equipo local y visitante y remates a puerta equipo local y visitante

# %%
remates_local = laliga.HS.sum()
remates_visitante = laliga.AS.sum()
rempor_local = laliga.HST.sum()
rempor_visitante = laliga.AST.sum()

mensaje = "Remates equipo local:                      {:5} ({:5.2f} por partido)"
print(mensaje.format(remates_local, round(remates_local/total_partidos, 2)))
mensaje = "Remates equipo vistante:                   {:5} ({:5.2f} por partido)"
print(mensaje.format(remates_visitante, round(remates_visitante/total_partidos, 2)))
mensaje = "Remates a puerta equipo local:             {:5} ({:5.2f} por partido)"
print(mensaje.format(rempor_local, round(rempor_local/total_partidos, 2)))
mensaje = "Remates a puerta equipo vistante:          {:5} ({:5.2f} por partido)"
print(mensaje.format(rempor_visitante, round(rempor_visitante/total_partidos, 2)))
# Out:
# Remates equipo local:                       5272 (13.87 por partido)
# Remates equipo vistante:                    3965 (10.43 por partido)
# Remates a puerta equipo local:              1837 ( 4.83 por partido)
# Remates a puerta equipo vistante:           1364 ( 3.59 por partido)

# %%
data = {'Tipo': ['Local', 'Visitante'], 'Remates': [remates_local, remates_visitante]}
remates = pd.DataFrame.from_dict(data)
remates
# Out:
#         Tipo  Remates
# 0      Local     5272
# 1  Visitante     3965

# %%
remates.groupby(['Tipo']).sum().plot.bar()

# %% [markdown]
# ### Real Madrid porcentaje de Victoria,Empates y Derrotas

# %% [markdown]
# #### Crea otro dataframe con el filtro de Real Madrid como equipo local y otro dataframe con las columnas del real madrid como visitante

# %%
df_realmadrid_l = laliga[(laliga.HomeTeam == 'Real Madrid')]
df_realmadrid_v = laliga[(laliga.AwayTeam == 'Real Madrid')]

df_realmadrid_l
# Out:
#           Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  SHHG  \
# 6   2018-08-19  Real Madrid      Getafe     2     0   H     1     0   H     1
# 24  2018-09-01  Real Madrid     Leganes     4     1   H     1     1   D     3
# 43  2018-09-22  Real Madrid     Espanol     1     0   H     1     0   H     0
# 62  2018-09-29  Real Madrid  Ath Madrid     0     0   D     0     0   D     0
# 81  2018-10-20  Real Madrid     Levante     1     2   A     0     2   A     1
# 101 2018-11-03  Real Madrid  Valladolid     2     0   H     0     0   D     2
# 133 2018-12-01  Real Madrid    Valencia     2     0   H     1     0   H     1
# 153 2018-12-15  Real Madrid   Vallecano     1     0   H     1     0   H     0
# 177 2019-01-06  Real Madrid    Sociedad     0     2   A     0     1   A     0
# 193 2019-01-19  Real Madrid     Sevilla     2     0   H     0     0   D     2
# 217 2019-02-03  Real Madrid      Alaves     3     0   H     1     0   H     2
# ...

# %% [markdown]
# ### Contar la cantidad de juegos ganados tanto de local, como visitante por el Real Madrid

# %%
rma_pg = df_realmadrid_l[df_realmadrid_l.FTR == "H"]['HomeTeam'].count() + df_realmadrid_v[df_realmadrid_v.FTR == 'A']['AwayTeam'].count()
print('El Real Madrid ganó {} juegos'.format(rma_pg))
# Out:
# El Real Madrid ganó 21 juegos

# %% [markdown]
# ### Lista los nombres de los clubes de la liga española

# %%
laliga.HomeTeam.unique()
# Out:
# array(['Betis', 'Girona', 'Barcelona', 'Celta', 'Villarreal', 'Eibar',
#        'Real Madrid', 'Vallecano', 'Ath Bilbao', 'Valencia', 'Getafe',
#        'Leganes', 'Alaves', 'Ath Madrid', 'Valladolid', 'Espanol',
#        'Sevilla', 'Levante', 'Huesca', 'Sociedad'], dtype=object)

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

@interact
def mostrar(columna= ['Ath Bilbao', 'Celta', 'Valencia', 'Mallorca', 'Leganes',
       'Villarreal', 'Alaves', 'Espanol', 'Betis', 'Ath Madrid',
       'Granada', 'Levante', 'Osasuna', 'Real Madrid', 'Getafe',
       'Barcelona', 'Sevilla', 'Sociedad', 'Eibar', 'Valladolid']):
    return laliga[(laliga.HomeTeam == columna)]
# Out:
# interactive(children=(Dropdown(description='columna', options=('Ath Bilbao', 'Celta', 'Valencia', 'Mallorca', …

# %%
@interact
def mostrar(columna= ['Ath Bilbao', 'Celta', 'Valencia', 'Mallorca', 'Leganes',
       'Villarreal', 'Alaves', 'Espanol', 'Betis', 'Ath Madrid',
       'Granada', 'Levante', 'Osasuna', 'Real Madrid', 'Getafe',
       'Barcelona', 'Sevilla', 'Sociedad', 'Eibar', 'Valladolid']):
    df_realmadrid_l = laliga[(laliga.HomeTeam == columna)]
    df_realmadrid_v = laliga[(laliga.AwayTeam == columna)]
    rma_pg = df_realmadrid_l[df_realmadrid_l.FTR == "H"]['HomeTeam'].count() + df_realmadrid_v[df_realmadrid_v.FTR == 'A']['AwayTeam'].count()
    return print('El {} ganó {} juegos'.format(columna, rma_pg))
# Out:
# interactive(children=(Dropdown(description='columna', options=('Ath Bilbao', 'Celta', 'Valencia', 'Mallorca', …

# %% [markdown]
# ### 3. La Tabla de Liga:
#
# * La tabla de la liga incluirá las siguientes columnas:
#     * Club: nombre del club.
#     * MP: total de partidos jugados.
#     * W: número total de victorias.
#     * D: número total de empates.
#     * L: número total de derrotas.
#     * GF: número total de goles marcados.
#     * GA: número total de goles recibidos.
#     * GD: diferencia de goles (GF-GA).
#     * Pts: puntos totales.

# %%
def crear_tabla(clubs, df, side):
    ## side = home/away/all
    ## home = para crear una tabla de los partidos locales de la liga
    ## away =  para crear una tabla de los partidos visitante de la liga
    ## all = para crear una tabla de todos los valores de la liga 
    
    #diccionario que incluirá la información de cada club
    league_table = dict()
    
    for club in clubs:
        ## iterate though club and fill in the values in league_table dictionary
        ## iterar a través del club y completar los valores en el diccionario league_table
        ## match played, win, draw, lose, goals for, goals against, goal difference, clean sheets, points
        mp, w, d, l, gf, ga, gd, cs, pts = 0, 0, 0, 0, 0, 0, 0, 0, 0
        

        ## recorrerá todo el conjunto de datos y calculará todos los resultados
        for i in range(len(df)):
            ## la cláusula if-else verificará las condiciones para los equipos locales y visitantes
            ## y según la condición calculará los resultados requeridos
            ## cuando el club es un equipo local
            ## el parámetro de side es para checkear si es unaa tabla de local o no
            if df.iloc[i]['HomeTeam'] == club and (side == 'home' or side == 'all'):
 
                if df.iloc[i]['FTR'] == 'H':
                    #cuando el equipo local gana, se suma 1 victoria y 3 puntos
                    w += 1
                    pts += 3
                    
                elif df.iloc[i]['FTR'] == 'A':
                    l += 1
                #cuando el equipo visitante gana, se suma 1 derrota y 0 puntos
  
                else:
                 #cuando se empata, se suma 1 empate y 0 puntos

                    d += 1
                    pts += 1
                    
                ##calculando los goles a favor y los goles en contra    
                gf += df.iloc[i]['FTHG']
                ga += df.iloc[i]['FTAG']
                
                
                 ## calculando los partidos con portería a 0
                if df.iloc[i]['FTAG'] == 0:
                    cs += 1
                
                ## incrementar la cantidad de partidos jugados
                mp += 1
                
                
            # cuando el club es un equipo visitante
            ## el parámetro de side es para checkear si es unaa tabla de visitante o no
            
            elif df.iloc[i]['AwayTeam'] == club and (side == 'away' or side == 'all'):

                if df.iloc[i]['FTR'] == 'H':
                    #cuando el equipo local gana, se suma 1 derrota  y 0 puntos
                    l += 1

                elif df.iloc[i]['FTR'] == 'A':
                   #cuando el equipo local pierde, se suma 1 victoria y 3 puntos
                    w += 1
                    pts += 3
                    
                else:
                #cuando se empata, se suma 1 empate y 0 puntos

                    d += 1
                    pts += 1

                ##calculando los goles a favor y los goles en contra    
                
                gf += df.iloc[i]['FTAG']
                ga += df.iloc[i]['FTHG']
                
                
                ## calculando los partidos con portería a 0
                if df.iloc[i]['FTHG'] == 0:
                    cs += 1

                ## incrementar la cantidad de partidos jugados
                mp += 1
        
        #calculando la diferencia de gol 
        gd = gf - ga
        
        ## colocando todos los parámetros en un diccionario con una llave que es el nombre del club
        league_table[club] = {'MP': mp, 'W': w, 'D': d, 'L': l, 'GF': gf, 'GA': ga, 'GD': gd, 'CS': cs, 'PTS': pts}
    
    return league_table

# %% [markdown]
# ### Asigna la fución crear_tabla(clubs, laliga, side='all') en una variable tabla_liga e imprimela

# %%
clubs = laliga['HomeTeam'].unique()

# %%
## call make_league_table
tabla_liga = crear_tabla(clubs, laliga, side='all')
tabla_liga
# Out:
# {'Betis': {'MP': 38,
#   'W': 14,
#   'D': 8,
#   'L': 16,
#   'GF': 44,
#   'GA': 52,
#   'GD': -8,
#   'CS': 11,
#   'PTS': 50},
#  'Girona': {'MP': 38,
#   'W': 9,
#   'D': 10,
#   'L': 19,
#   'GF': 37,
#   'GA': 53,
#   'GD': -16,
#   'CS': 9,
#   'PTS': 37},
#  'Barcelona': {'MP': 38,
#   'W': 26,
#   'D': 9,
#   'L': 3,
#   'GF': 90,
#   'GA': 36,
#   'GD': 54,
#   'CS': 17,
#   'PTS': 87},
#  'Celta': {'MP': 38,
#   'W': 10,
#   'D': 11,
#   'L': 17,
#   'GF': 53,
#   'GA': 62,
#   'GD': -9,
#   'CS': 8,
#   'PTS': 41},
#  'Villarreal': {'MP': 38,
#   'W': 10,
#   'D': 14,
#   'L': 14,
#   'GF': 49,
#   'GA': 52,
#   'GD': -3,
#   'CS': 11,
#   'PTS': 44},
#  'Eibar': {'MP': 38,
#   'W': 11,
#   'D': 14,
#   'L': 13,
#   'GF': 46,
#   'GA': 50,
#   'GD': -4,
#   'CS': 9,
#   'PTS': 47},
#  'Real Madrid': {'MP': 38,
#   'W': 21,
#   'D': 5,
#   'L': 12,
#   'GF': 63,
#   'GA': 46,
#   'GD': 17,
#   'CS': 12,
#   'PTS': 68},
#  'Vallecano': {'MP': 38,
#   'W': 8,
#   'D': 8,
# ...

# %% [markdown]
# ### Crear un dataframe llamado tabla_liga_df con el diccionario tabla_liga

# %%
tabla_liga_df = pd.DataFrame(tabla_liga)
tabla_liga_df
# Out:
#      Betis  Girona  Barcelona  Celta  Villarreal  Eibar  Real Madrid  \
# MP      38      38         38     38          38     38           38
# W       14       9         26     10          10     11           21
# D        8      10          9     11          14     14            5
# L       16      19          3     17          14     13           12
# GF      44      37         90     53          49     46           63
# GA      52      53         36     62          52     50           46
# GD      -8     -16         54     -9          -3     -4           17
# CS      11       9         17      8          11      9           12
# PTS     50      37         87     41          44     47           68
#
#      Vallecano  Ath Bilbao  Valencia  Getafe  Leganes  Alaves  Ath Madrid  \
# MP          38          38        38      38       38      38          38
# W            8          13        15      15       11      13          22
# ...

# %% [markdown]
# ### Convertir columnas en filas y filas en columnas, usando .transpose()

# %%
tabla_liga_df = tabla_liga_df.transpose()
tabla_liga_df
# Out:
#              MP   W   D   L  GF  GA  GD  CS  PTS
# Betis        38  14   8  16  44  52  -8  11   50
# Girona       38   9  10  19  37  53 -16   9   37
# Barcelona    38  26   9   3  90  36  54  17   87
# Celta        38  10  11  17  53  62  -9   8   41
# Villarreal   38  10  14  14  49  52  -3  11   44
# Eibar        38  11  14  13  46  50  -4   9   47
# Real Madrid  38  21   5  12  63  46  17  12   68
# Vallecano    38   8   8  22  41  70 -29   7   32
# Ath Bilbao   38  13  14  11  41  45  -4  10   53
# Valencia     38  15  16   7  51  35  16  13   61
# Getafe       38  15  14   9  48  35  13  13   59
# Leganes      38  11  12  15  37  43  -6  11   45
# Alaves       38  13  11  14  39  50 -11   8   50
# Ath Madrid   38  22  10   6  55  29  26  20   76
# Valladolid   38  10  11  17  32  51 -19   9   41
# Espanol      38  14  11  13  48  50  -2  10   53
# Sevilla      38  17   8  13  62  47  15  11   59
# Levante      38  11  11  16  59  66  -7   7   44
# ...

# %% [markdown]
# ### Convierte el Club en una columna y resetea índice

# %%
tabla_liga_df = tabla_liga_df.rename_axis('Club').reset_index()
tabla_liga_df
# Out:
#            Club  MP   W   D   L  GF  GA  GD  CS  PTS
# 0         Betis  38  14   8  16  44  52  -8  11   50
# 1        Girona  38   9  10  19  37  53 -16   9   37
# 2     Barcelona  38  26   9   3  90  36  54  17   87
# 3         Celta  38  10  11  17  53  62  -9   8   41
# 4    Villarreal  38  10  14  14  49  52  -3  11   44
# 5         Eibar  38  11  14  13  46  50  -4   9   47
# 6   Real Madrid  38  21   5  12  63  46  17  12   68
# 7     Vallecano  38   8   8  22  41  70 -29   7   32
# 8    Ath Bilbao  38  13  14  11  41  45  -4  10   53
# 9      Valencia  38  15  16   7  51  35  16  13   61
# 10       Getafe  38  15  14   9  48  35  13  13   59
# 11      Leganes  38  11  12  15  37  43  -6  11   45
# 12       Alaves  38  13  11  14  39  50 -11   8   50
# 13   Ath Madrid  38  22  10   6  55  29  26  20   76
# 14   Valladolid  38  10  11  17  32  51 -19   9   41
# 15      Espanol  38  14  11  13  48  50  -2  10   53
# 16      Sevilla  38  17   8  13  62  47  15  11   59
# ...

# %% [markdown]
# ### Ordena los valores por la columna PTS y Goles de Diferencia (GD)  y resetea los indices

# %%
tabla_liga_df.sort_values(by=['PTS', 'GD'], ascending=False, inplace=True)
tabla_liga_df.reset_index(inplace=True, drop=True)
tabla_liga_df
# Out:
#            Club  MP   W   D   L  GF  GA  GD  CS  PTS
# 0     Barcelona  38  26   9   3  90  36  54  17   87
# 1    Ath Madrid  38  22  10   6  55  29  26  20   76
# 2   Real Madrid  38  21   5  12  63  46  17  12   68
# 3      Valencia  38  15  16   7  51  35  16  13   61
# 4       Sevilla  38  17   8  13  62  47  15  11   59
# 5        Getafe  38  15  14   9  48  35  13  13   59
# 6       Espanol  38  14  11  13  48  50  -2  10   53
# 7    Ath Bilbao  38  13  14  11  41  45  -4  10   53
# 8      Sociedad  38  13  11  14  45  46  -1   9   50
# 9         Betis  38  14   8  16  44  52  -8  11   50
# 10       Alaves  38  13  11  14  39  50 -11   8   50
# 11        Eibar  38  11  14  13  46  50  -4   9   47
# 12      Leganes  38  11  12  15  37  43  -6  11   45
# 13   Villarreal  38  10  14  14  49  52  -3  11   44
# 14      Levante  38  11  11  16  59  66  -7   7   44
# 15        Celta  38  10  11  17  53  62  -9   8   41
# 16   Valladolid  38  10  11  17  32  51 -19   9   41
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Análisis de datos exploratorios (EDA):

# %% [markdown]
# * **Muestra los 4 equipos clasificados a la UEFA Champions League(UCL).**

# %%
tabla_liga_df.iloc[:4]['Club']
# Out:
# 0      Barcelona
# 1     Ath Madrid
# 2    Real Madrid
# 3       Valencia
# Name: Club, dtype: object

# %% [markdown]
# * **Muestra los 3 equipos calificados a la UEFA Europa League(UEL).**

# %%
tabla_liga_df.iloc[4:7]['Club']
# Out:
# 4    Sevilla
# 5     Getafe
# 6    Espanol
# Name: Club, dtype: object

# %% [markdown]
# * **Muestra los 3 equipos desendidos**

# %%
tabla_liga_df.iloc[19:16:-1]['Club']
# Out:
# 19    Vallecano
# 18       Huesca
# 17       Girona
# Name: Club, dtype: object

# %%
vector = []
for index, row in tabla_liga_df.iterrows():
    if 0 <= index <= 3:
        vector.append('Clasificado a Champions League')
    elif 4<= index <=6:
        vector.append('Clasificado a Europa League')
    elif 17<= index <=19:
        vector.append('Descendido')
    else:
        vector.append('No va a competiciones Europeas')
        
vector
# Out:
# ['Clasificado a Champions League',
#  'Clasificado a Champions League',
#  'Clasificado a Champions League',
#  'Clasificado a Champions League',
#  'Clasificado a Europa League',
#  'Clasificado a Europa League',
#  'Clasificado a Europa League',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'No va a competiciones Europeas',
#  'Descendido',
#  'Descendido',
#  'Descendido']

# %%
def clasificado(x):
    if 0 <= x.name <= 3:
        return 'Clasificado a Champions League'
    elif 4<= x.name <=6:
        return 'Clasificado a Europa League'
    elif 17<= x.name <=19:
        return 'Descendido'
    else:
        return 'No va a competiciones Europeas'

# %%
tabla_liga_df['CE'] = tabla_liga_df.apply(lambda x: clasificado(x), axis=1)

# %%
tabla_liga_df
# Out:
#            Club  MP   W   D   L  GF  GA  GD  CS  PTS  \
# 0     Barcelona  38  26   9   3  90  36  54  17   87
# 1    Ath Madrid  38  22  10   6  55  29  26  20   76
# 2   Real Madrid  38  21   5  12  63  46  17  12   68
# 3      Valencia  38  15  16   7  51  35  16  13   61
# 4       Sevilla  38  17   8  13  62  47  15  11   59
# 5        Getafe  38  15  14   9  48  35  13  13   59
# 6       Espanol  38  14  11  13  48  50  -2  10   53
# 7    Ath Bilbao  38  13  14  11  41  45  -4  10   53
# 8      Sociedad  38  13  11  14  45  46  -1   9   50
# 9         Betis  38  14   8  16  44  52  -8  11   50
# 10       Alaves  38  13  11  14  39  50 -11   8   50
# 11        Eibar  38  11  14  13  46  50  -4   9   47
# 12      Leganes  38  11  12  15  37  43  -6  11   45
# 13   Villarreal  38  10  14  14  49  52  -3  11   44
# 14      Levante  38  11  11  16  59  66  -7   7   44
# 15        Celta  38  10  11  17  53  62  -9   8   41
# 16   Valladolid  38  10  11  17  32  51 -19   9   41
# ...

# %% [markdown]
# * **5 equipos con mayor número de goles**

# %%
tabla_liga_df.sort_values(by='GF', ascending=False)[:5][['Club', 'GF']]
# Out:
#            Club  GF
# 0     Barcelona  90
# 2   Real Madrid  63
# 4       Sevilla  62
# 14      Levante  59
# 1    Ath Madrid  55

# %% [markdown]
# * **5 equipos con menor número de goles**

# %%
tabla_liga_df.sort_values(by='GF')[:5][['Club', 'GF']]
# Out:
#           Club  GF
# 16  Valladolid  32
# 17      Girona  37
# 12     Leganes  37
# 10      Alaves  39
# 19   Vallecano  41

# %% [markdown]
# * **5 equipos con mayor portería a 0.**

# %%
tabla_liga_df.sort_values(by='CS', ascending=False)[:5][['Club', 'CS']]
# Out:
#           Club  CS
# 1   Ath Madrid  20
# 0    Barcelona  17
# 3     Valencia  13
# 5       Getafe  13
# 2  Real Madrid  12

# %% [markdown]
# * **Los cinco mejores equipos que concedieron la mayor cantidad de goles**

# %%
tabla_liga_df.sort_values(by='GA', ascending=False)[:5][['Club', 'GA']]
# Out:
#          Club  GA
# 19  Vallecano  70
# 14    Levante  66
# 18     Huesca  65
# 15      Celta  62
# 17     Girona  53

# %% [markdown]
# * ## **Tabla Local y Tabla Visitante**

# %% [markdown]
# ### Asigna la fución crear_tabla(clubs, laliga, side='home') en una variable llamada tabla_local e imprimela

# %%
tabla_local = crear_tabla(clubs, laliga, side='home')
tabla_local
# Out:
# {'Betis': {'MP': 19,
#   'W': 8,
#   'D': 5,
#   'L': 6,
#   'GF': 25,
#   'GA': 26,
#   'GD': -1,
#   'CS': 5,
#   'PTS': 29},
#  'Girona': {'MP': 19,
#   'W': 3,
#   'D': 6,
#   'L': 10,
#   'GF': 17,
#   'GA': 28,
#   'GD': -11,
#   'CS': 4,
#   'PTS': 15},
#  'Barcelona': {'MP': 19,
#   'W': 15,
#   'D': 3,
#   'L': 1,
#   'GF': 51,
#   'GA': 17,
#   'GD': 34,
#   'CS': 9,
#   'PTS': 48},
#  'Celta': {'MP': 19,
#   'W': 8,
#   'D': 5,
#   'L': 6,
#   'GF': 31,
#   'GA': 25,
#   'GD': 6,
#   'CS': 6,
#   'PTS': 29},
#  'Villarreal': {'MP': 19,
#   'W': 5,
#   'D': 8,
#   'L': 6,
#   'GF': 28,
#   'GA': 26,
#   'GD': 2,
#   'CS': 3,
#   'PTS': 23},
#  'Eibar': {'MP': 19,
#   'W': 9,
#   'D': 6,
#   'L': 4,
#   'GF': 31,
#   'GA': 21,
#   'GD': 10,
#   'CS': 7,
#   'PTS': 33},
#  'Real Madrid': {'MP': 19,
#   'W': 13,
#   'D': 1,
#   'L': 5,
#   'GF': 32,
#   'GA': 15,
#   'GD': 17,
#   'CS': 10,
#   'PTS': 40},
#  'Vallecano': {'MP': 19,
#   'W': 5,
#   'D': 6,
#   'L': 8,
# ...

# %% [markdown]
# ## Realiza el mismo preprocesamiento que con tabla_liga_df

# %% [markdown]
# * Crear un dataframe llamado tabla_local_df con el diccionario tabla_local
# * transponer el dataframe tabla_local
# * Colocar el index Club como una nueva columna y reseteear el index como numérico
# * Ordenar el dataframe por puntos y goles de diferencia de mayor a menor
# * Resetear los índices con el dataframe ordenado

# %%
tabla_local_df = crear_tabla(clubs, laliga, side='home')

tabla_local_df = pd.DataFrame(tabla_local)
tabla_local_df = tabla_local_df.transpose()

tabla_local_df = tabla_local_df.rename_axis('Club').reset_index()
tabla_local_df.sort_values(by=['PTS', 'GD'], ascending=False, inplace=True)

tabla_local_df.reset_index(inplace=True, drop=True)
tabla_local_df
# Out:
#            Club  MP   W   D   L  GF  GA  GD  CS  PTS
# 0     Barcelona  19  15   3   1  51  17  34   9   48
# 1    Ath Madrid  19  15   3   1  32  10  22  13   48
# 2   Real Madrid  19  13   1   5  32  15  17  10   40
# 3       Sevilla  19  12   3   4  39  20  19   8   39
# 4        Getafe  19  11   3   5  28  13  15  10   36
# 5       Espanol  19  11   3   5  28  22   6   7   36
# 6    Ath Bilbao  19   9   8   2  26  19   7   7   35
# 7         Eibar  19   9   6   4  31  21  10   7   33
# 8      Valencia  19   7  10   2  24  12  12   7   31
# 9         Celta  19   8   5   6  31  25   6   6   29
# 10      Leganes  19   7   8   4  19  16   3   7   29
# 11       Alaves  19   7   8   4  19  19   0   5   29
# 12        Betis  19   8   5   6  25  26  -1   5   29
# 13     Sociedad  19   7   6   6  23  20   3   4   27
# 14      Levante  19   6   7   6  34  34   0   5   25
# 15   Villarreal  19   5   8   6  28  26   2   3   23
# 16       Huesca  19   5   6   8  24  30  -6   3   21
# ...

# %% [markdown]
# ### Realiza lo mismo anterior pero con side='away' en la funcion  crear_tabla(clubs, laliga, side='away'). Usar de variable tabla_visitante y tabla_visitante_df

# %%
tabla_visitante = crear_tabla(clubs, laliga, side='away')

tabla_visitante_df = pd.DataFrame(tabla_visitante)

tabla_visitante_df = tabla_visitante_df.transpose()


tabla_visitante_df = tabla_visitante_df.rename_axis('Club').reset_index()

tabla_visitante_df.sort_values(by=['PTS', 'GD'], ascending=False, inplace=True)

tabla_visitante_df.reset_index(inplace=True, drop=True)

tabla_visitante_df
# Out:
#            Club  MP   W   D   L  GF  GA  GD  CS  PTS
# 0     Barcelona  19  11   6   2  39  19  20   8   39
# 1      Valencia  19   8   6   5  27  23   4   6   30
# 2    Ath Madrid  19   7   7   5  23  19   4   7   28
# 3   Real Madrid  19   8   4   7  31  31   0   2   28
# 4        Getafe  19   4  11   4  20  22  -2   3   23
# 5      Sociedad  19   6   5   8  22  26  -4   5   23
# 6        Girona  19   6   4   9  20  25  -5   5   22
# 7    Villarreal  19   5   6   8  21  26  -5   8   21
# 8         Betis  19   6   3  10  19  26  -7   6   21
# 9    Valladolid  19   5   6   8  16  25  -9   4   21
# 10       Alaves  19   6   3  10  20  31 -11   3   21
# 11      Sevilla  19   5   5   9  23  27  -4   3   20
# 12      Levante  19   5   4  10  25  32  -7   2   19
# 13   Ath Bilbao  19   4   6   9  15  26 -11   3   18
# 14      Espanol  19   3   8   8  20  28  -8   3   17
# 15      Leganes  19   4   4  11  18  27  -9   4   16
# 16        Eibar  19   2   8   9  15  29 -14   2   14
# ...

# %%
## mostrando los marcos de datos resultantes
## la primera tabla es para los partidos en casa y la segunda es para los partidos fuera de casa

def multi_table(table_list):
    return HTML(
        '<table><tr style="background-color:white;">' + 
        ''.join(['<td>' + table._repr_html_() + '</td>' for table in table_list]) +
        '</tr></table>'
    )
multi_table([tabla_local_df, tabla_visitante_df])
# Out:
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Club</th>
#       <th>MP</th>
#       <th>W</th>
#       <th>D</th>
#       <th>L</th>
#       <th>GF</th>
#       <th>GA</th>
#       <th>GD</th>
#       <th>CS</th>
#       <th>PTS</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Barcelona</td>
#       <td>19</td>
#       <td>15</td>
#       <td>3</td>
#       <td>1</td>
#       <td>51</td>
#       <td>17</td>
#       <td>34</td>
#       <td>9</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Ath Madrid</td>
#       <td>19</td>
#       <td>15</td>
# ...

# %% [markdown]
# * ***Conclusion***:  Todos los equipos cuando jugaron sus partidos fuera de casa, perdieron puntos, en comparación a jugar de local
#
# <br>

# %% [markdown]
# ### Promedio de goles marcados por cada equipo en cada mitad

# %%
uno = laliga.groupby(by='HomeTeam')['HTHG'].sum().to_frame()

# %%
dos = laliga.groupby(by='AwayTeam')['HTAG'].sum().to_frame()

# %%
media_goles_primer_tiempo = uno.join(dos)

# %%
media_goles_primer_tiempo['Suma de Goles'] = (media_goles_primer_tiempo['HTHG'] + media_goles_primer_tiempo['HTAG'])

# %%
media_goles_primer_tiempo['Promedio de Goles Primer Tiempo'] = media_goles_primer_tiempo['Suma de Goles']/38

# %%
media_goles_primer_tiempo.sort_values(by='Promedio de Goles Primer Tiempo', ascending=False, inplace=True)
media_goles_primer_tiempo
# Out:
#              HTHG  HTAG  Suma de Goles  Promedio de Goles Primer Tiempo
# HomeTeam
# Barcelona      18    19             37                         0.973684
# Valencia        9    17             26                         0.684211
# Levante        18     8             26                         0.684211
# Real Madrid    10    14             24                         0.631579
# Vallecano      13    10             23                         0.605263
# Espanol        10    13             23                         0.605263
# Ath Bilbao     14     9             23                         0.605263
# Ath Madrid     12    10             22                         0.578947
# Sociedad       12    10             22                         0.578947
# Girona         11    10             21                         0.552632
# Sevilla        12     7             19                         0.500000
# Alaves          9     9             18                         0.473684
# ...

# %%
tres = laliga.groupby(by='HomeTeam')['SHHG'].sum().to_frame()
tres
cuatro = laliga.groupby(by='AwayTeam')['SHAG'].sum().to_frame()
cuatro
# Out:
#              SHAG
# AwayTeam
# Alaves         11
# Ath Bilbao      6
# Ath Madrid     13
# Barcelona      20
# Betis          15
# Celta          13
# Eibar           8
# Espanol         7
# Getafe         13
# Girona         10
# Huesca         10
# Leganes        10
# Levante        17
# Real Madrid    17
# Sevilla        16
# Sociedad       12
# Valencia       10
# Valladolid     10
# Vallecano       6
# Villarreal     12

# %%
media_goles_segundo_tiempo = tres.join(cuatro)

# %%
media_goles_segundo_tiempo['Suma de Goles'] = (media_goles_segundo_tiempo['SHHG'] + media_goles_segundo_tiempo['SHAG'])
media_goles_segundo_tiempo.head()
# Out:
#             SHHG  SHAG  Suma de Goles
# HomeTeam
# Alaves        10    11             21
# Ath Bilbao    12     6             18
# Ath Madrid    20    13             33
# Barcelona     33    20             53
# Betis         18    15             33

# %%
media_goles_segundo_tiempo['Promedio de Goles Segundo Tiempo'] = media_goles_segundo_tiempo['Suma de Goles']/38
media_goles_segundo_tiempo.head()
# Out:
#             SHHG  SHAG  Suma de Goles  Promedio de Goles Segundo Tiempo
# HomeTeam
# Alaves        10    11             21                          0.552632
# Ath Bilbao    12     6             18                          0.473684
# Ath Madrid    20    13             33                          0.868421
# Barcelona     33    20             53                          1.394737
# Betis         18    15             33                          0.868421

# %%
media_goles_segundo_tiempo.sort_values(by='Promedio de Goles Segundo Tiempo', ascending=False, inplace=True)
media_goles_segundo_tiempo.head()
# Out:
#              SHHG  SHAG  Suma de Goles  Promedio de Goles Segundo Tiempo
# HomeTeam
# Barcelona      33    20             53                          1.394737
# Sevilla        27    16             43                          1.131579
# Real Madrid    22    17             39                          1.026316
# Celta          22    13             35                          0.921053
# Villarreal     21    12             33                          0.868421

# %%
media_goles_primer_tiempo.rename(index={'HomeTeam': 'Club'}, inplace=True)
media_goles_segundo_tiempo.rename(index={'HomeTeam': 'Club'}, inplace=True)

# %%
multi_table([media_goles_primer_tiempo[['Promedio de Goles Primer Tiempo']],media_goles_segundo_tiempo[['Promedio de Goles Segundo Tiempo']]])
# Out:
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Promedio de Goles Primer Tiempo</th>
#     </tr>
#     <tr>
#       <th>HomeTeam</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Barcelona</th>
#       <td>0.973684</td>
#     </tr>
#     <tr>
#       <th>Valencia</th>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <th>Levante</th>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <th>Real Madrid</th>
#       <td>0.631579</td>
#     </tr>
#     <tr>
#       <th>Vallecano</th>
#       <td>0.605263</td>
#     </tr>
#     <tr>
#       <th>Espanol</th>
# ...

# %% [markdown]
# * **Conclusión**: Bueno, lo primero y más importante que podemos ver aquí es que la mayoría de los aumentos promedio en la tasa de goles en la segunda mitad. Las razones pueden ser sustituciones efectivas, oposiciones que se cansan en la segunda mitad, etc. Pero se puede ver que el Barcelona es el que más alto tiene el promedio, sin embargo, en los segundo tiempos bajó el promedio y esto puede ser determinante una razón por la que perdió la liga, mientras que el Madrid subió considerablemente el promedio en los segundos tiempos

# %% [markdown]
# ## Promedio de goles concedido por cada equipo en cada tiempo

# %%
uno = laliga.groupby(by='HomeTeam')['HTAG'].sum().to_frame()

# %%
dos = laliga.groupby(by='AwayTeam')['HTHG'].sum().to_frame()

# %%
media_recibidos_primer_tiempo = uno.join(dos)

# %%
media_recibidos_primer_tiempo['Suma de Goles'] = (media_recibidos_primer_tiempo['HTHG'] + media_recibidos_primer_tiempo['HTAG'])

# %%
media_recibidos_primer_tiempo['Promedio de Goles Recibidos Primer Tiempo'] = media_recibidos_primer_tiempo['Suma de Goles']/38

# %%
media_recibidos_primer_tiempo.sort_values(by='Promedio de Goles Recibidos Primer Tiempo', ascending=False, inplace=True)
media_recibidos_primer_tiempo
# Out:
#              HTAG  HTHG  Suma de Goles  \
# HomeTeam
# Huesca         15    15             30
# Vallecano      15    11             26
# Celta          10    16             26
# Betis          15    10             25
# Real Madrid     8    16             24
# Levante        14     9             23
# Alaves          8    15             23
# Eibar          12    11             23
# Sevilla        10    12             22
# Sociedad       10    12             22
# Valladolid     11    10             21
# Espanol        12     6             18
# Barcelona       9     9             18
# Villarreal      8    10             18
# Leganes        11     6             17
# Girona          9     7             16
# Ath Bilbao      5    10             15
# Getafe          6     7             13
# Valencia        3    10             13
# Ath Madrid      4     5              9
#
#              Promedio de Goles Recibidos Primer Tiempo
# HomeTeam
# ...

# %%
tres = laliga.groupby(by='HomeTeam')['SHAG'].sum().to_frame()
tres
cuatro = laliga.groupby(by='AwayTeam')['SHHG'].sum().to_frame()

# %%
media_recibidos_segundo_tiempo = tres.join(cuatro)

# %%
media_recibidos_segundo_tiempo['Suma de Goles'] = (media_recibidos_segundo_tiempo['SHHG'] + media_recibidos_segundo_tiempo['SHAG'])
media_recibidos_segundo_tiempo.head()
# Out:
#             SHAG  SHHG  Suma de Goles
# HomeTeam
# Alaves        11    16             27
# Ath Bilbao    14    16             30
# Ath Madrid     6    14             20
# Barcelona      8    10             18
# Betis         11    16             27

# %%
media_recibidos_segundo_tiempo['Promedio de Goles Recibidos Segundo Tiempo'] = media_recibidos_segundo_tiempo['Suma de Goles']/38
media_recibidos_segundo_tiempo.head()
# Out:
#             SHAG  SHHG  Suma de Goles  \
# HomeTeam
# Alaves        11    16             27
# Ath Bilbao    14    16             30
# Ath Madrid     6    14             20
# Barcelona      8    10             18
# Betis         11    16             27
#
#             Promedio de Goles Recibidos Segundo Tiempo
# HomeTeam
# Alaves                                        0.710526
# Ath Bilbao                                    0.789474
# Ath Madrid                                    0.526316
# Barcelona                                     0.473684
# Betis                                         0.710526

# %%
media_recibidos_segundo_tiempo.sort_values(by='Promedio de Goles Recibidos Segundo Tiempo', ascending=False, inplace=True)
media_recibidos_segundo_tiempo.head()
# Out:
#            SHAG  SHHG  Suma de Goles  \
# HomeTeam
# Vallecano    17    27             44
# Levante      20    23             43
# Girona       19    18             37
# Celta        15    21             36
# Huesca       15    20             35
#
#            Promedio de Goles Recibidos Segundo Tiempo
# HomeTeam
# Vallecano                                    1.157895
# Levante                                      1.131579
# Girona                                       0.973684
# Celta                                        0.947368
# Huesca                                       0.921053

# %%
multi_table([media_recibidos_primer_tiempo[['Promedio de Goles Recibidos Primer Tiempo']],media_recibidos_segundo_tiempo[['Promedio de Goles Recibidos Segundo Tiempo']]])
# Out:
# <table><tr style="background-color:white;"><td><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Promedio de Goles Recibidos Primer Tiempo</th>
#     </tr>
#     <tr>
#       <th>HomeTeam</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Huesca</th>
#       <td>0.789474</td>
#     </tr>
#     <tr>
#       <th>Vallecano</th>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <th>Celta</th>
#       <td>0.684211</td>
#     </tr>
#     <tr>
#       <th>Betis</th>
#       <td>0.657895</td>
#     </tr>
#     <tr>
#       <th>Real Madrid</th>
#       <td>0.631579</td>
#     </tr>
#     <tr>
#       <th>Levante</th>
# ...

# %% [markdown]
# * ***Conclusión***: Bueno, del análisis anterior se puede concluir que el objetivo promedio concedido para la mayoría del equipo aumentó en la segunda mitad. Ahora echemos un vistazo a algunos de los equipos que llaman la atención.
